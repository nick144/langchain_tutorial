# %% [markdown]
# # **LLM CALL**

# %%
import os
from openai import OpenAI

api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise RuntimeError(
        "OPENAI_API_KEY is not set. Set it in your environment before running this notebook."
    )

client = OpenAI(api_key=api_key)
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {
            "role": "user",
            "content": "Bro, tell me a joke about programming."
        }
    ])

print(response.choices[0].message.content)
# Out:
# Bro: Why do programmers prefer dark mode? Because light attracts bugs.

# %%
from langchain_openai import ChatOpenAI

llm_openai = ChatOpenAI(model="gpt-5-nano", temperature=0)
llm_openai.invoke("Bro, tell me the fun fact")
# print(response)
# Out:
# AIMessage(content='Bro, here’s a wild one: bananas are botanically berries, but strawberries aren’t. \n\nWhy? In plant terms a “berry” comes from a single ovary and has seeds embedded in the flesh — bananas fit that. Strawberries are “aggregate accessory fruits” (the tiny bits you see are the actual fruits). Want another fun fact?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 400, 'prompt_tokens': 13, 'total_tokens': 413, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DadI1YZSdBlTMGfofyFICeMc5qr8c', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019de299-8e8c-7d93-bb08-618f3cc2b4ea-0', tool_calls=[], invalid_tool_calls=[], usage_meta
# ...

# %%
from langchain.chat_models import init_chat_model

llm_chat_models = init_chat_model(model="gpt-5-nano", temperature=0)
llm_chat_models.invoke("Bro, tell me the fun fact")

# %%
from langchain_openai import ChatOpenAI
import os
from load_dotenv import load_dotenv

load_dotenv()
# Out:
# True
